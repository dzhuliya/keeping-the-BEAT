# %% [markdown]
# You should be able to run this notebook with the test files included in the zipped file. You will need to redefine your out_dir and spectra paths before actually running the fits for yourself.

# %%
import beat
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-5344471331f7> in <module>
# ----> 1 import beat
#
# ModuleNotFoundError: No module named 'beat'

# %%
import numpy as np
import os

# %% [markdown]
# The user should define their own function to load their files
#
# Given a path, your function should return "row", "column", "wave", "flux", and "noise"
#
# For example if a file is named "ic5063_150_155.txt" and has 3 columns of data - wave, flux, and noise.
#
# Then you would want to pull 150 and 155 out of the file name as your row and column.
#
# And then use loadtxt or whatever you prefer to read in your data and name your columns accordingly.
#
# The following load_file works for the files included in the example folder.

# %%
def load_file(filepath):
    """returns row and column of spaxel along with wave, flux, and noise arrays to pass to fitting code"""
    path, infile = os.path.split(filepath)
    infilebase = infile.split('.')[0]
    column = infilebase.split('_')[1]  # spaxel column coordinate (x)
    row = infilebase.split('_')[2]
    wave, flux, noise = np.loadtxt(filepath, usecols=(0, 1, 2), unpack=True, delimiter=',')
    return row, column, wave, flux, noise

# %% [markdown]
# You'll need to define two different dictionaries, named here "target_param" and "fit_instructions".
#
# Target param will include:
# - name - your target name
# - red - redshift of your object
# - minwidth - minimum width that should be attempted to be fit
# - maxwidth - maximum width that should be attempted to be fit
# - start - the start of your data in array space (I'll change this soon, I swear lol)
# - end - the end of your data in array space (and this of course)
# - fluxsigma - value to multiply flux sigma by to keep or reject a fit
# - continuum1 - continuum area to the left of your line(s)
# - continuum2 - continuum area to the right of your line(s)
# - plotmin - x-axis minimum for output plots (wavelength)
# - plotmax - x-axis maximum for output plots
# - maxcomp - the maximum number of components that should be attempted per line
# - lnz - evidence value difference needed to accept a fit with more components. 5.0 is standard, a number larger than 5 will make it harder for a fit with more components to be chosen
# - cores - # processes for multiprocessing pool
#
# Fit instructions will include information about the lines you want to fit:
# - line1 - this should be your 'main' line that other lines would be locked with, if specified
#     - name - name of your line which will be used to name the output file
#     - wave - rest wavelength of line
#     - minwave - minimum wavelength that should be fit for this one line
#     - wave_range - (minwave, minwave + wave_range) will be the allowed wavelengths for the centroid of any component (right?)
#     - flux_free - is this line's flux locked in with any other line? For line 1 this will be False
# - line2 - this would be a second line that you would like to fit in tandem with line1. most parameters are identical as line1, except:
#     - flux_free will be False if this line is locked with another line
#     - locked_with - which line is this line locked with ("line1")
#     - flux_ratio - what is the flux ratio between the two lines [line1 = (flux_ratio)*line2]
# - more lines may be added ('line3', 'line4', etc) - remember to list any lines that will have flux_free = True before any lines that rely on that line
#
# Call the 'Fit' class instance - define an output directory, specify where your data files are, pass your target parameters and fit instructions.
#
# Finally call mp_handler to start the fits

# %%
def main():
    target_param = {'name': 'ic5063', 'red': 0.01135, 'minwidth': 1.43, 'maxwidth': 33.83,
                    'start': 10, 'end': 450, 'fluxsigma': 3, 'continuum1': (4962, 5000),
                    'continuum2': (5087, 5125), 'plotmin': 4900, 'plotmax': 5150, 'maxcomp': 3, 
                    'lnz': 5.0, 'cores' : 2} 

    """fit_instructions = {
        'line1': {'name': 'oiii', 'wave': 5006.84, 'minwave': 5054, 'wave_range': 20.0, 'flux_free': True},
        'line2': {'name': 'oiii', 'wave': 4958.92, 'flux_free': False, 'locked_with': 'line1', 'flux_ratio': 3}
        }"""
    fit_instructions = {
        'line1': {'name': 'oiii', 'wave': 5006.84, 'minwave': 5054, 'wave_range': 20.0, 'flux_free': True},
        'line2': {'name': 'oiii', 'wave': 4958.92, 'flux_free': False, 'locked_with': 'line1', 'flux_ratio': 3},
        'line3': {'name': 'h-beta', 'wave': 4861.33, 'minwave': 4911, 'wave_range': 15.0, 'flux_free': True}
        }


    fit = beat.Fit(out_dir='ic5063/',
                   spec_dir='spectra',
                   load_file=load_file,
                   fit_instructions=fit_instructions,
                   target_param=target_param
                   )
    fit.mp_handler()

# %% [markdown]
# call main() or whatever function you put your dictionaries and fit call
#
# try stopping and restarting the fits

# %%
main()
# Out:
# remaining to fit: 31
# Fitting Pixel: 150, 151
# Fitting Pixel: 128, 131
# Min Y: 2.63e-17
# Min Y: 6.55e-18
# Max Y: 9.14e-17
# Max Y: 6.64e-16
# Pixel: 128, 131 trying 1 component(s)
# Pixel: 150, 151 trying 1 component(s)
# Pixel: 128, 131 trying 2 component(s)
# Pixel: 150, 151 trying 2 component(s)
# Pixel: 128, 131 trying 3 component(s)
# Pixel: 150, 151 trying 3 component(s)
# Pixel: 128, 131 fit with 2 components
# Average Continuum = 9.89e-18
# Standard deviation = 9.6661e-19
# Fitting Pixel: 144, 149
# Min Y: 1.70e-17
# Max Y: 3.41e-16
# Pixel: 144, 149 trying 1 component(s)
# Pixel: 144, 149 trying 2 component(s)
# Pixel: 144, 149 trying 3 component(s)
# Pixel: 150, 151 fit with 3 components
# Average Continuum = 3.46e-17
# Standard deviation = 1.8780e-18
# Fitting Pixel: 150, 152
# Min Y: 2.29e-17
# Max Y: 5.54e-16
# Pixel: 150, 152 trying 1 component(s)
# Pixel: 150, 152 trying 2 component(s)
# Pixel: 144, 149 fit with 2 components
# Average Continuum = 2.31e-17
# Standard deviation = 1.3260e-18
# Fitting Pixel: 150, 149
# Min Y: 2.35e-17
# Max Y: 1.05e-15
# Pixel: 150, 149 trying 1 component(s)
# Pixel: 150, 152 trying 3 component(s)
# Pixel: 150, 149 trying 2 component(s)
# Pixel: 150, 149 trying 3 component(s)
# Pixel: 150, 152 fit with 3 components
# Average Continuum = 3.43e-17
# Standard deviation = 1.5663e-18
# Fitting Pixel: 150, 153
# Min Y: 2.33e-17
# Max Y: 4.51e-16
# Pixel: 150, 153 trying 1 component(s)
# Pixel: 150, 153 trying 2 component(s)
# Pixel: 150, 153 trying 3 component(s)
# Pixel: 150, 149 fit with 3 components
# Average Continuum = 3.40e-17
# Standard deviation = 1.8536e-18
# Fitting Pixel: 150, 150
# Min Y: 2.39e-17
# Max Y: 8.15e-16
# Pixel: 150, 150 trying 1 component(s)
# Pixel: 150, 150 trying 2 component(s)
# Pixel: 150, 150 trying 3 component(s)
# Pixel: 150, 153 fit with 3 components
# Average Continuum = 3.41e-17
# Standard deviation = 1.8151e-18
# Fitting Pixel: 150, 154
# Min Y: 2.40e-17
# Max Y: 3.43e-16
# Pixel: 150, 154 trying 1 component(s)
# Pixel: 150, 154 trying 2 component(s)
# Pixel: 150, 154 trying 3 component(s)
# Pixel: 150, 150 fit with 3 components
# Average Continuum = 3.43e-17
# Standard deviation = 1.6116e-18
# Fitting Pixel: 150, 155
# Min Y: 2.48e-17
# Max Y: 2.78e-16
# Pixel: 150, 155 trying 1 component(s)
# Pixel: 150, 155 trying 2 component(s)
# Pixel: 150, 154 fit with 3 components
# Average Continuum = 3.44e-17
# Standard deviation = 1.8032e-18
# Fitting Pixel: 151, 149
# Min Y: 2.77e-17
# Max Y: 1.33e-15
# Pixel: 151, 149 trying 1 component(s)
# Pixel: 150, 155 trying 3 component(s)
# Pixel: 151, 149 trying 2 component(s)
# Pixel: 150, 155 fit with 3 components
# Average Continuum = 3.43e-17
# Standard deviation = 1.9873e-18
# Fitting Pixel: 150, 156
# Min Y: 2.29e-17
# Max Y: 2.16e-16
# Pixel: 150, 156 trying 1 component(s)
# Pixel: 151, 149 trying 3 component(s)
# Pixel: 150, 156 trying 2 component(s)
# Pixel: 150, 156 trying 3 component(s)
# Pixel: 150, 156 fit with 3 components
# Average Continuum = 3.36e-17
# Standard deviation = 1.8433e-18
# Fitting Pixel: 150, 157
# Min Y: 2.36e-17
# Max Y: 1.72e-16
# Pixel: 150, 157 trying 1 component(s)
# Pixel: 150, 157 trying 2 component(s)
# Pixel: 150, 157 trying 3 component(s)
# Pixel: 151, 149 fit with 3 components
# Average Continuum = 3.68e-17
# Standard deviation = 1.7451e-18
# Fitting Pixel: 151, 150
# Min Y: 2.68e-17
# Max Y: 1.08e-15
# Pixel: 151, 150 trying 1 component(s)
# Pixel: 151, 150 trying 2 component(s)
# Pixel: 151, 150 trying 3 component(s)
# Pixel: 150, 157 fit with 2 components
# Average Continuum = 3.32e-17
# Standard deviation = 1.5745e-18
# Fitting Pixel: 151, 148
# Min Y: 2.65e-17
# Max Y: 1.65e-15
# Pixel: 151, 148 trying 1 component(s)
# Pixel: 151, 148 trying 2 component(s)
# Pixel: 151, 148 trying 3 component(s)
# Pixel: 151, 150 fit with 3 components
# Average Continuum = 3.73e-17
# Standard deviation = 1.8209e-18
# Fitting Pixel: 151, 151
# Min Y: 2.73e-17
# Max Y: 8.56e-16
# Pixel: 151, 151 trying 1 component(s)
# Pixel: 151, 151 trying 2 component(s)
# Pixel: 151, 151 trying 3 component(s)
# Pixel: 151, 151 fit with 3 components
# Average Continuum = 3.79e-17
# Standard deviation = 1.7556e-18
# Fitting Pixel: 151, 152
# Min Y: 2.62e-17
# Max Y: 7.22e-16
# Pixel: 151, 152 trying 1 component(s)
# Pixel: 151, 148 fit with 3 components
# Average Continuum = 3.61e-17
# Standard deviation = 1.9704e-18
# Fitting Pixel: 151, 153
# Min Y: 2.84e-17
# Max Y: 5.71e-16
# Pixel: 151, 153 trying 1 component(s)
# Pixel: 151, 152 trying 2 component(s)
# Pixel: 151, 153 trying 2 component(s)
# Pixel: 151, 152 trying 3 component(s)
# Pixel: 151, 153 trying 3 component(s)
# Pixel: 151, 153 fit with 3 components
# Average Continuum = 3.81e-17
# Standard deviation = 1.8122e-18
# Fitting Pixel: 151, 154
# Min Y: 2.78e-17
# Max Y: 4.34e-16
# Pixel: 151, 154 trying 1 component(s)
# Pixel: 151, 152 fit with 3 components
# Average Continuum = 3.77e-17
# Standard deviation = 1.7663e-18
# Fitting Pixel: 152, 147
# Min Y: 2.56e-17
# Max Y: 2.32e-15
# Pixel: 152, 147 trying 1 component(s)
# Pixel: 151, 154 trying 2 component(s)
# Pixel: 152, 147 trying 2 component(s)
# Pixel: 151, 154 trying 3 component(s)
# Pixel: 152, 147 trying 3 component(s)
# Pixel: 151, 154 fit with 3 components
# Average Continuum = 3.73e-17
# Standard deviation = 2.0942e-18
# Fitting Pixel: 151, 155
# Min Y: 2.76e-17
# Max Y: 3.38e-16
# Pixel: 151, 155 trying 1 component(s)
# Pixel: 151, 155 trying 2 component(s)
# Pixel: 152, 147 fit with 3 components
# Average Continuum = 3.63e-17
# Standard deviation = 2.0476e-18
# Fitting Pixel: 152, 148
# Min Y: 2.76e-17
# Max Y: 2.03e-15
# Pixel: 152, 148 trying 1 component(s)
# Pixel: 152, 148 trying 2 component(s)
# Pixel: 151, 155 trying 3 component(s)
# Pixel: 152, 148 trying 3 component(s)
# Pixel: 151, 155 fit with 3 components
# Average Continuum = 3.70e-17
# Standard deviation = 1.9896e-18
# Fitting Pixel: 151, 156
# Min Y: 2.73e-17
# Max Y: 2.65e-16
# Pixel: 151, 156 trying 1 component(s)
# Pixel: 151, 156 trying 2 component(s)
# Pixel: 151, 156 trying 3 component(s)
# Pixel: 152, 148 fit with 3 components
# Average Continuum = 3.84e-17
# Standard deviation = 2.1194e-18
# Fitting Pixel: 152, 149
# Min Y: 2.86e-17
# Max Y: 1.69e-15
# Pixel: 152, 149 trying 1 component(s)
# Pixel: 152, 149 trying 2 component(s)
# Pixel: 151, 156 fit with 3 components
# Average Continuum = 3.66e-17
# Standard deviation = 2.0292e-18
# Fitting Pixel: 152, 151
# Min Y: 3.02e-17
# Max Y: 1.13e-15
# Pixel: 152, 151 trying 1 component(s)
# Pixel: 152, 151 trying 2 component(s)
# Pixel: 152, 149 trying 3 component(s)
# Pixel: 152, 151 trying 3 component(s)
# Pixel: 152, 149 fit with 3 components
# Average Continuum = 3.92e-17
# Standard deviation = 1.8707e-18
# Fitting Pixel: 152, 150
# Min Y: 2.97e-17
# Max Y: 1.38e-15
# Pixel: 152, 150 trying 1 component(s)
# Pixel: 152, 151 fit with 3 components
# Average Continuum = 4.13e-17
# Standard deviation = 1.8542e-18
# Fitting Pixel: 152, 152
# Min Y: 3.01e-17
# Max Y: 9.14e-16
# Pixel: 152, 152 trying 1 component(s)
# Pixel: 152, 152 trying 2 component(s)
# Pixel: 152, 150 trying 2 component(s)
# Pixel: 152, 152 trying 3 component(s)
# Pixel: 152, 150 trying 3 component(s)
# Pixel: 152, 152 fit with 3 components
# Average Continuum = 4.10e-17
# Standard deviation = 2.1052e-18
# Fitting Pixel: 152, 153
# Min Y: 3.06e-17
# Max Y: 7.19e-16
# Pixel: 152, 153 trying 1 component(s)
# Pixel: 152, 153 trying 2 component(s)
# Pixel: 152, 150 fit with 3 components
# Average Continuum = 4.02e-17
# Standard deviation = 2.3139e-18
# Fitting Pixel: 152, 155
# Min Y: 3.09e-17
# Max Y: 4.10e-16
# Pixel: 152, 155 trying 1 component(s)
# Pixel: 152, 155 trying 2 component(s)
# Pixel: 152, 153 trying 3 component(s)
# Pixel: 152, 155 trying 3 component(s)
# Pixel: 152, 155 fit with 3 components
# Average Continuum = 4.12e-17
# Standard deviation = 1.9817e-18
# Fitting Pixel: 157, 207
# Min Y: 4.54e-18
# Max Y: 1.29e-17
# Pixel: 157, 207 trying 1 component(s)
# Pixel: 157, 207 trying 2 component(s)
# Pixel: 152, 153 fit with 3 components
# Average Continuum = 4.16e-17
# Standard deviation = 2.2659e-18
# Fitting Pixel: 152, 154
# Min Y: 3.16e-17
# Max Y: 5.31e-16
# Pixel: 152, 154 trying 1 component(s)
# Pixel: 152, 154 trying 2 component(s)
# Pixel: 157, 207 fit with 1 components
# Average Continuum = 8.12e-18
# Standard deviation = 8.1045e-19
# Fitting Pixel: 205, 193
# Min Y: 4.17e-18
# Max Y: 9.88e-17
# Pixel: 205, 193 trying 1 component(s)
# Pixel: 205, 193 trying 2 component(s)
# Pixel: 152, 154 trying 3 component(s)
# Pixel: 205, 193 trying 3 component(s)
# Pixel: 205, 193 fit with 2 components
# Average Continuum = 6.85e-18
# Standard deviation = 8.2771e-19
# Pixel: 152, 154 fit with 3 components
# Average Continuum = 4.14e-17
# Standard deviation = 1.9759e-18
